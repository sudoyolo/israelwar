# %% [markdown]
# <a href="https://colab.research.google.com/github/sudoyolo/israelwar/blob/main/model_evals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# utilities
import re
import pickle
import numpy as np
import pandas as pd

# plotting
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff


# nltk
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# important libraries
from bokeh.plotting import figure
from bokeh.io import output_file, show, output_notebook
from collections import Counter
import spacy
from spacy.util import compounding
from spacy.util import minibatch
from spacy import displacy
import gc
import os

# sklearn
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # BERNOULLI

# %%
import matplotlib.pyplot as plt

# Class names
classes = ['negative', 'neutral', 'positive']

# Precision values
precision = [0.71, 0.00, 0.00]

# Recall values
recall = [0.99, 0.00, 0.00]

# F1-score values
f1_score = [0.83, 0.00, 0.00]

# Support values
support = [141, 48, 11]

# Plotting
plt.bar(classes, precision, color='red', alpha=0.5)
plt.bar(classes, recall, color='green', alpha=0.5)
plt.bar(classes, f1_score, color='blue', alpha=0.5)
plt.bar(classes, support, color='orange', alpha=0.5)

# Customizing the graph
plt.legend(['Precision', 'Recall', 'F1-score', 'Support'])
plt.title('Classification Report')
plt.xlabel('Classes')
plt.ylabel('Values')

# Displaying the graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Class names
classes = ['negative', 'neutral', 'positive']

# Precision values
precision = [0.71, 0.00, 0.00]

# Recall values
recall = [0.99, 0.00, 0.00]

# F1-score values
f1_score = [0.83, 0.00, 0.00]

# Support values
support = [141, 48, 11]

# Subplot 1: Precision, Recall, F1-score
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(classes, precision, marker='o', label='Precision')
axs[0].plot(classes, recall, marker='o', label='Recall')
axs[0].plot(classes, f1_score, marker='o', label='F1-score')
axs[0].set_title('Precision, Recall, and F1-score')
axs[0].set_xlabel('Classes')
axs[0].set_ylabel('Values')
axs[0].legend()

# Subplot 2: Support
axs[1].plot(classes, support, color='orange', alpha=0.5)
axs[1].set_title('Support')
axs[1].set_xlabel('Classes')
axs[1].set_ylabel('Values')

# Displaying the graph
plt.show()

# %% [markdown]
# # K NEAREST NEIGHBOURS

# %%
import matplotlib.pyplot as plt

# Class names
classes = ['negative', 'neutral', 'positive']

# Precision values
precision = [0.72, 0.29, 1.00]

# Recall values
recall = [0.94, 0.08, 0.09]

# F1-score values
f1_score = [0.82, 0.13, 0.17]

# Support values
support = [141, 48, 11]

# Subplot 1: Precision, Recall, F1-score
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(classes, precision, marker='o', label='Precision')
axs[0].plot(classes, recall, marker='o', label='Recall')
axs[0].plot(classes, f1_score, marker='o', label='F1-score')
axs[0].set_title('Precision, Recall, and F1-score')
axs[0].set_xlabel('Classes')
axs[0].set_ylabel('Values')
axs[0].legend()

# Subplot 2: Support
axs[1].plot(classes, support, color='orange', alpha=0.5)
axs[1].set_title('Support')
axs[1].set_xlabel('Classes')
axs[1].set_ylabel('Values')

# Displaying the graph
plt.show()

# %% [markdown]
# # DECISION TREE

# %%
import matplotlib.pyplot as plt

# Class names
classes = ['negative', 'neutral', 'positive']

# Precision values
precision = [0.70, 0.25, 0.00]

# Recall values
recall = [0.70, 0.27, 0.00]

# F1-score values
f1_score = [0.70, 0.26, 0.00]

# Support values
support = [141, 48, 11]

# Subplot 1: Precision, Recall, F1-score
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(classes, precision, marker='o', label='Precision')
axs[0].plot(classes, recall, marker='o', label='Recall')
axs[0].plot(classes, f1_score, marker='o', label='F1-score')
axs[0].set_title('Precision, Recall, and F1-score')
axs[0].set_xlabel('Classes')
axs[0].set_ylabel('Values')
axs[0].legend()

# Subplot 2: Support
axs[1].plot(classes, support, color='orange', alpha=0.5)
axs[1].set_title('Support')
axs[1].set_xlabel('Classes')
axs[1].set_ylabel('Values')

# Displaying the graph
plt.show()

# %% [markdown]
# # RANDOM FOREST

# %%
import matplotlib.pyplot as plt

# Class names
classes = ['negative', 'neutral', 'positive']

# Precision values
precision = [0.72, 0.67, 0.00]

# Recall values
recall = [0.99, 0.08, 0.00]

# F1-score values
f1_score = [0.83, 0.15, 0.00]

# Support values
support = [141, 48, 11]

# Subplot 1: Precision, Recall, F1-score
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(classes, precision, marker='o', label='Precision')
axs[0].plot(classes, recall, marker='o', label='Recall')
axs[0].plot(classes, f1_score, marker='o', label='F1-score')
axs[0].set_title('Precision, Recall, and F1-score')
axs[0].set_xlabel('Classes')
axs[0].set_ylabel('Values')
axs[0].legend()

# Subplot 2: Support
axs[1].plot(classes, support, color='orange', alpha=0.5)
axs[1].set_title('Support')
axs[1].set_xlabel('Classes')
axs[1].set_ylabel('Values')

# Displaying the graph
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
import matplotlib.pyplot as plt

# Class names
classes = ['negative', 'neutral', 'positive']

# Precision values
precision = [0.71, 0.50, 0.00]

# Recall values
recall = [0.99, 0.02, 0.00]

# F1-score values
f1_score = [0.83, 0.04, 0.00]

# Support values
support = [141, 48, 11]

# Subplot 1: Precision, Recall, F1-score
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].plot(classes, precision, marker='o', label='Precision')
axs[0].plot(classes, recall, marker='o', label='Recall')
axs[0].plot(classes, f1_score, marker='o', label='F1-score')
axs[0].set_title('Precision, Recall, and F1-score')
axs[0].set_xlabel('Classes')
axs[0].set_ylabel('Values')
axs[0].legend()

# Subplot 2: Support
axs[1].plot(classes, support, color='orange', alpha=0.5)
axs[1].set_title('Support')
axs[1].set_xlabel('Classes')
axs[1].set_ylabel('Values')

# Displaying the graph
plt.show()
